# %% [markdown]
# ![UML%20Image.png](attachment:UML%20Image.png)

# %% [markdown]
# Comment: This is My NeuronalCell class , and then PyramidalCell and OvoidCell classes inherit from it, but have different params, and opeartions for each.
